# %%
import ccxt
import pandas as pd
from datetime import datetime, timedelta

# %%
# Initialize ccxt and set parameters
exchanges = ccxt.exchanges
target_pair = 'BTC/USDT' 
timeframe = '1d' 
since = int((datetime.now() - timedelta(days=180)).timestamp() * 1000)  # Last 6 months in ms

# Store results of arbitrage opportunities
arbitrage_opportunities = []

# %%
# Helper function to fetch OHLCV data and store the last price
def fetch_last_price(exchange, pair):
    try:
        ohlcv = exchange.fetch_ohlcv(pair, timeframe, since)
        # Convert to DataFrame for easier analysis
        df = pd.DataFrame(ohlcv, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
        df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
        return df[['timestamp', 'close']]
    except Exception as e:
        print(f"Error fetching data from {exchange.name}: {str(e)}")
        return None

# %%
ignore_exchanges = ['ndax', 'wazirx', 'bitteam']

# Loop through all ccxt exchanges
for exchange_id in exchanges:
    if exchange_id in ignore_exchanges:  # Skip due to conversion issues
        continue
    try:
        # Initialize and load markets
        exchange = getattr(ccxt, exchange_id)()
        exchange.load_markets()  # Ensure markets are loaded

        # Check if the target pair is supported
        if target_pair in exchange.symbols:
            print(f"Fetching data for {target_pair} on {exchange_id}...")
            prices = fetch_last_price(exchange, target_pair)
            if prices is not None:
                arbitrage_opportunities.append((exchange_id, prices))
        else:
            print(f"{target_pair} not available on {exchange_id}")
    except Exception as e:
        print(f"Error initializing {exchange_id}: {str(e)}")
# Out:
# Error initializing ace: ace GET https://ace.io/polarisex/oapi/v2/list/marketPair
# Error initializing alpaca: alpaca requires "apiKey" credential
# Fetching data for BTC/USDT on ascendex...
# Fetching data for BTC/USDT on bequant...
# Fetching data for BTC/USDT on bigone...
# Error initializing binance: binance GET https://api.binance.com/api/v3/exchangeInfo
# Error initializing binancecoinm: binancecoinm GET https://dapi.binance.com/dapi/v1/exchangeInfo
# Error initializing binanceus: binanceus GET https://api.binance.us/api/v3/exchangeInfo
# Error initializing binanceusdm: binanceusdm GET https://fapi.binance.com/fapi/v1/exchangeInfo
# Error initializing bingx: bingx GET https://open-api.bingx.com/openApi/swap/v2/quote/contracts?timestamp=1738450513153
# BTC/USDT not available on bit2c
# Error initializing bitbank: bitbank GET https://api.bitbank.cc/spot/pairs
# Fetching data for BTC/USDT on bitbns...
# Error fetching data from Bitbns: bitbns fetchOHLCV() is not supported yet. If you want to build OHLCV candles from trade executions data, visit https://github.com/ccxt/ccxt/tree/master/examples/ and see "build-ohlcv-bars" file
# Fetching data for BTC/USDT on bitcoincom...
# Error initializing bitfinex: bitfinex GET https://api-pub.bitfinex.com/v2/conf/pub:list:currency,pub:map:currency:sym,pub:map:currency:label,pub:map:currency:unit,pub:map:currency:undl,pub:map:currency:pool,pub:map:currency:explorer,pub:map:currency:tx:fee,pub:map:tx:method
# Error initializing bitfinex1: bitfinex1 GET https://api.bitfinex.com/v1/symbols
# Error initializing bitflyer: bitflyer GET https://api.bitflyer.com/v1/getmarkets
# Error initializing bitget: bitget GET https://api.bitget.com/api/v2/spot/public/coins
# Error initializing bithumb: bithumb GET https://api.bithumb.com/public/ticker/ALL_BTC
# Fetching data for BTC/USDT on bitmart...
# Error initializing bitmex: bitmex GET https://www.bitmex.com/api/v1/wallet/assets
# Fetching data for BTC/USDT on bitopro...
# Error fetching data from BitoPro: bitopro {"error":"Wrong parameter: wrong timestamp"}
# BTC/USDT not available on bitpanda
# Error initializing bitrue: bitrue GET https://www.bitrue.com/api/v1/exchangeInfo
# Error initializing bitso: bitso GET https://bitso.com/api/v3/available_books
# Error initializing bitstamp: bitstamp GET https://www.bitstamp.net/api/v2/trading-pairs-info/
# Error initializing bitvavo: bitvavo GET https://api.bitvavo.com/v2/assets
# BTC/USDT not available on bl3p
# Error initializing blockchaincom: blockchaincom GET https://api.blockchain.com/v3/exchange/symbols
# BTC/USDT not available on blofin
# Error initializing btcalpha: btcalpha GET https://btc-alpha.com/api/v1/pairs/
# BTC/USDT not available on btcbox
# Error initializing btcmarkets: btcmarkets GET https://api.btcmarkets.net/v3/markets
# Error initializing btcturk: btcturk GET https://api.btcturk.com/api/v2/server/exchangeinfo
# Error initializing bybit: bybit GET https://api.bybit.com/v5/market/instruments-info?category=spot
# Error initializing cex: cex POST https://trade.cex.io/api/spot/rest-public/get_currencies_info
# Error initializing coinbase: coinbase GET https://api.coinbase.com/v2/currencies
# Error initializing coinbaseadvanced: coinbaseadvanced GET https://api.coinbase.com/v2/currencies
# Error initializing coinbaseexchange: coinbaseexchange GET https://api.exchange.coinbase.com/currencies
# Error initializing coinbaseinternational: coinbaseinternational GET https://api.international.coinbase.com/api/v1/assets
# Fetching data for BTC/USDT on coincatch...
# BTC/USDT not available on coincheck
# Fetching data for BTC/USDT on coinex...
# Fetching data for BTC/USDT on coinlist...
# Error fetching data from Coinlist: coinlist {"status":401,"message":"\"granularity\" must be one of , 5m, 30m]"}
# Error initializing coinmate: coinmate GET https://coinmate.io/api/tradingPairs
# Fetching data for BTC/USDT on coinmetro...
# Error initializing coinone: coinone GET https://api.coinone.co.kr/public/v2/currencies
# Fetching data for BTC/USDT on coinsph...
# BTC/USDT not available on coinspot
# Error initializing cryptocom: cryptocom GET https://api.crypto.com/exchange/v1/public/get-instruments
# Fetching data for BTC/USDT on currencycom...
# BTC/USDT not available on defx
# Error initializing delta: delta GET https://api.delta.exchange/v2/assets
# Fetching data for BTC/USDT on deribit...
# Fetching data for BTC/USDT on digifinex...
# Error initializing ellipx: ellipx GET https://app.ellipx.com/_rest/Crypto/Token/Info?Can_Deposit=Y&results_per_page=100&_expand=%2FCrypto_Token%2C%2FCrypto_Chain
# Error initializing exmo: exmo GET https://api.exmo.com/v1.1/currency/list/extended
# Fetching data for BTC/USDT on fmfwio...
# Error initializing gate: gate GET https://api.gateio.ws/api/v4/spot/currencies
# Error initializing gateio: gateio GET https://api.gateio.ws/api/v4/spot/currencies
# Error initializing gemini: gemini GET https://api.gemini.com/v1/symbols
# Error initializing hashkey: hashkey GET https://api-glb.hashkey.com/api/v1/exchangeInfo
# Error initializing hitbtc: hitbtc GET https://api.hitbtc.com/api/3/public/currency
# Fetching data for BTC/USDT on hollaex...
# Fetching data for BTC/USDT on htx...
# Fetching data for BTC/USDT on huobi...
# BTC/USDT not available on huobijp
# Error initializing hyperliquid: hyperliquid POST https://api.hyperliquid.xyz/info
# Error initializing idex: idex GET https://api-matic.idex.io/v1/assets
# Error initializing independentreserve: independentreserve GET https://api.independentreserve.com/Public/GetValidPrimaryCurrencyCodes
# Fetching data for BTC/USDT on indodax...
# Error initializing kraken: kraken GET https://api.kraken.com/0/public/Assets
# Error initializing krakenfutures: krakenfutures GET https://futures.kraken.com/derivatives/api/v3/instruments
# Error initializing kucoin: kucoin GET https://api.kucoin.com/api/v3/currencies
# Error initializing kucoinfutures: kucoinfutures GET https://api-futures.kucoin.com/api/v1/contracts/active
# Fetching data for BTC/USDT on kuna...
# Error fetching data from Kuna: kuna fetchOHLCV() is not supported yet. If you want to build OHLCV candles from trade executions data, visit https://github.com/ccxt/ccxt/tree/master/examples/ and see "build-ohlcv-bars" file
# Error initializing latoken: latoken GET https://api.latoken.com/v2/currency
# Error initializing lbank: lbank GET https://lbkperp.lbank.com/cfd/openApi/v1/pub/instrument?productGroup=SwapU
# Error initializing luno: luno GET https://api.luno.com/api/exchange/1/markets
# Error initializing lykke: lykke GET https://hft-apiv2.lykke.com/api/assets
# BTC/USDT not available on mercado
# Fetching data for BTC/USDT on mexc...
# Error initializing myokx: myokx GET https://eea.okx.com/api/v5/public/instruments?instType=SPOT
# Fetching data for BTC/USDT on novadax...
# Fetching data for BTC/USDT on oceanex...
# Error initializing okcoin: okcoin GET https://www.okcoin.com/api/v5/public/instruments?instType=SPOT
# Error initializing okx: okx GET https://www.okx.com/api/v5/public/instruments?instType=SPOT
# BTC/USDT not available on onetrading
# BTC/USDT not available on oxfun
# Fetching data for BTC/USDT on p2b...
# BTC/USDT not available on paradex
# BTC/USDT not available on paymium
# Error initializing phemex: phemex GET https://api.phemex.com/public/products
# Error initializing poloniex: poloniex GET https://api.poloniex.com/currencies?includeMultiChainCurrencies=true
# Error initializing poloniexfutures: poloniexfutures GET https://futures-api.poloniex.com/api/v1/contracts/active
# Fetching data for BTC/USDT on probit...
# Fetching data for BTC/USDT on timex...
# Error initializing tokocrypto: tokocrypto GET https://www.tokocrypto.com/open/v1/common/symbols 451  <body><embed src='/not-support' type='text/html' style='width:100%;height:100vh;'/></body>
# Fetching data for BTC/USDT on tradeogre...
# Error fetching data from tradeogre: tradeogre fetchOHLCV() is not supported yet. If you want to build OHLCV candles from trade executions data, visit https://github.com/ccxt/ccxt/tree/master/examples/ and see "build-ohlcv-bars" file
# Error initializing upbit: upbit GET https://api.upbit.com/v1/market/all
# BTC/USDT not available on vertex
# BTC/USDT not available on wavesexchange
# Fetching data for BTC/USDT on whitebit...
# Fetching data for BTC/USDT on woo...
# BTC/USDT not available on woofipro
# Fetching data for BTC/USDT on xt...
# Error initializing yobit: yobit GET https://yobit.net/api/3/info
# Error initializing zaif: zaif GET https://api.zaif.jp/api/1/currency_pairs/all
# Fetching data for BTC/USDT on zonda...

# %%
# Calculate arbitrage opportunities
if len(arbitrage_opportunities) > 1:
    # Pairwise comparison of exchanges
    arbitrage_results = []
    for i in range(len(arbitrage_opportunities)):
        for j in range(i + 1, len(arbitrage_opportunities)):
            exchange1, prices1 = arbitrage_opportunities[i]
            exchange2, prices2 = arbitrage_opportunities[j]

            # Merge DataFrames on timestamp
            merged = prices1.merge(prices2, on='timestamp', suffixes=(f"_{exchange1}", f"_{exchange2}"))
            
            # Calculate price differences and arbitrage percentage
            merged['price_diff'] = abs(merged[f'close_{exchange1}'] - merged[f'close_{exchange2}'])
            merged['arbitrage_percent'] = (merged['price_diff'] / merged[[f'close_{exchange1}', f'close_{exchange2}']].min(axis=1)) * 100
            
            # Identify significant opportunities (arbitrage > 1%)
            significant_opportunities = merged[merged['arbitrage_percent'] > 1]
            if not significant_opportunities.empty:
                result = {
                    'exchange1': exchange1,
                    'exchange2': exchange2,
                    'average_arbitrage_percent': significant_opportunities['arbitrage_percent'].mean(),
                    'max_arbitrage_percent': significant_opportunities['arbitrage_percent'].max(),
                    'opportunity_count': len(significant_opportunities)
                }
                arbitrage_results.append(result)

    # Display results
    results_df = pd.DataFrame(arbitrage_results)
    if not results_df.empty:
        results_df = results_df.sort_values(by='average_arbitrage_percent', ascending=False)
        print(results_df)
        results_df.to_csv('arbitrage_results.csv', index=False)
    else:
        print("No significant arbitrage opportunities found.")
else:
    print("Insufficient exchanges found with historical data for the target pair.")
# Out:
# [('ascendex',      timestamp      close
# 0   2024-08-06   56024.50
# 1   2024-08-07   55140.03
# 2   2024-08-08   61686.20
# 3   2024-08-09   60831.01
# 4   2024-08-10   60928.59
# ..         ...        ...
# 175 2025-01-28  101346.39
# 176 2025-01-29  103730.80
# 177 2025-01-30  104729.24
# 178 2025-01-31  102440.93
# 179 2025-02-01  100556.60
#
# [180 rows x 2 columns]), ('bequant',     timestamp      close
# 0  2024-10-25   66786.50
# 1  2024-10-26   67098.24
# 2  2024-10-27   68021.60
# 3  2024-10-28   69964.97
# 4  2024-10-29   72731.63
# ..        ...        ...
# 95 2025-01-28  101390.98
# 96 2025-01-29  103752.45
# 97 2025-01-30  104729.85
# 98 2025-01-31  102422.98
# 99 2025-02-01  100552.64
#
# [100 rows x 2 columns]), ('bigone',     timestamp     close
# 0  2024-08-06  56030.00
# 1  2024-08-07  55130.00
# 2  2024-08-08  61682.02
# 3  2024-08-09  60827.99
# 4  2024-08-10  60906.23
# ..        ...       ...
# 95 2024-11-09  76677.46
# 96 2024-11-10  80381.07
# 97 2024-11-11  88647.99
# 98 2024-11-12  87952.00
# 99 2024-11-13  90375.21
#
# [100 rows x 2 columns]), ('bitcoincom',     timestamp      close
# 0  2024-10-25   66786.50
# 1  2024-10-26   67098.24
# 2  2024-10-27   68021.60
# 3  2024-10-28   69964.97
# 4  2024-10-29   72731.63
# ..        ...        ...
# 95 2025-01-28  101390.98
# 96 2025-01-29  103752.45
# 97 2025-01-30  104729.85
# 98 2025-01-31  102422.98
# 99 2025-02-01  100533.46
#
# [100 rows x 2 columns]), ('bitmart',     timestamp     close
# 0  2024-08-06  56024.00
# 1  2024-08-07  55135.97
# 2  2024-08-08  61686.00
# 3  2024-08-09  60828.01
# 4  2024-08-10  60923.52
# ..        ...       ...
# 94 2024-11-08  76509.77
# 95 2024-11-09  76677.45
# 96 2024-11-10  80373.24
# 97 2024-11-11  88648.00
# 98 2024-11-12  87952.01
#
# [99 rows x 2 columns]), ('coincatch',               timestamp      close
# 0   2024-08-06 16:00:00   56099.31
# 1   2024-08-07 16:00:00   59427.95
# 2   2024-08-08 16:00:00   59809.96
# 3   2024-08-09 16:00:00   60516.77
# 4   2024-08-10 16:00:00   60127.64
# ..                  ...        ...
# 175 2025-01-28 16:00:00  101982.20
# 176 2025-01-29 16:00:00  105564.41
# 177 2025-01-30 16:00:00  105458.93
# 178 2025-01-31 16:00:00  102072.44
# 179 2025-02-01 16:00:00  100617.84
#
# [180 rows x 2 columns]), ('coinex',     timestamp      close
# 0  2024-10-25   66735.75
# 1  2024-10-26   67084.09
# 2  2024-10-27   68011.50
# 3  2024-10-28   69940.30
# 4  2024-10-29   72732.97
# ..        ...        ...
# 95 2025-01-28  101332.98
# 96 2025-01-29  103731.48
# 97 2025-01-30  104714.28
# 98 2025-01-31  102406.43
# 99 2025-02-01  100653.53
#
# [100 rows x 2 columns]), ('coinmetro',      timestamp          close
# 0   2024-08-06   56123.790346
# 1   2024-08-07   55123.769135
# 2   2024-08-08   61687.526404
# 3   2024-08-09   60854.551361
# 4   2024-08-10   60933.022749
# ..         ...            ...
# 176 2025-01-29  103765.746890
# 177 2025-01-30  104736.813423
# 178 2025-01-31  102433.687222
# 179 2025-01-31  102433.687222
# 180 2025-02-01  100619.645554
#
# [181 rows x 2 columns]), ('coinsph',      timestamp      close
# 0   2024-08-06   56231.13
# 1   2024-08-07   55164.71
# 2   2024-08-08   61277.27
# 3   2024-08-09   61235.92
# 4   2024-08-10   60924.41
# ..         ...        ...
# 175 2025-01-28  101041.72
# 176 2025-01-29  104020.61
# 177 2025-01-30  104743.47
# 178 2025-01-31  102349.07
# 179 2025-02-01  100686.27
#
# [180 rows x 2 columns]), ('currencycom',      timestamp     close
# 0   2024-08-06   56049.8
# 1   2024-08-07   55115.3
# 2   2024-08-08   61692.4
# 3   2024-08-09   60848.3
# 4   2024-08-10   60902.3
# ..         ...       ...
# 175 2025-01-28  101365.6
# 176 2025-01-29  103697.1
# 177 2025-01-30  104710.2
# 178 2025-01-31  102418.6
# 179 2025-02-01  100666.0
#
# [180 rows x 2 columns]), ('deribit',               timestamp     close
# 0   2024-08-06 08:00:00   56904.0
# 1   2024-08-07 08:00:00   57171.0
# 2   2024-08-08 08:00:00   60900.0
# 3   2024-08-09 08:00:00   60863.0
# 4   2024-08-10 08:00:00   61268.0
# ..                  ...       ...
# 175 2025-01-28 08:00:00  102662.0
# 176 2025-01-29 08:00:00  105112.0
# 177 2025-01-30 08:00:00  104191.0
# 178 2025-01-31 08:00:00  102196.0
# 179 2025-02-01 08:00:00  100500.0
#
# [180 rows x 2 columns]), ('digifinex',               timestamp      close
# 0   2024-08-06 16:00:00   56094.50
# 1   2024-08-07 16:00:00   59419.11
# 2   2024-08-08 16:00:00   59813.00
# 3   2024-08-09 16:00:00   60509.79
# 4   2024-08-10 16:00:00   60123.99
# ..                  ...        ...
# 175 2025-01-28 16:00:00  101980.32
# 176 2025-01-29 16:00:00  105564.00
# 177 2025-01-30 16:00:00  105421.30
# 178 2025-01-31 16:00:00  102073.88
# 179 2025-02-01 16:00:00  100611.44
#
# [180 rows x 2 columns]), ('fmfwio',     timestamp      close
# 0  2024-10-25   66786.50
# 1  2024-10-26   67098.24
# 2  2024-10-27   68021.60
# 3  2024-10-28   69964.97
# 4  2024-10-29   72731.63
# ..        ...        ...
# 95 2025-01-28  101390.98
# 96 2025-01-29  103752.45
# 97 2025-01-30  104729.85
# 98 2025-01-31  102422.98
# 99 2025-02-01  100640.68
#
# [100 rows x 2 columns]), ('hollaex',      timestamp      close
# 0   2024-08-06   56023.27
# 1   2024-08-07   55046.28
# 2   2024-08-08   61830.94
# 3   2024-08-09   60843.82
# 4   2024-08-10   60913.57
# ..         ...        ...
# 175 2025-01-28  101427.75
# 176 2025-01-29  103640.21
# 177 2025-01-30  104698.89
# 178 2025-01-31  102365.53
# 179 2025-02-01  100700.88
#
# [180 rows x 2 columns]), ('htx',               timestamp     close
# 0   2024-08-06 16:00:00  56099.55
# 1   2024-08-07 16:00:00  59422.08
# 2   2024-08-08 16:00:00  59826.94
# 3   2024-08-09 16:00:00  60512.98
# 4   2024-08-10 16:00:00  60118.47
# ..                  ...       ...
# 145 2024-12-29 16:00:00  92124.04
# 146 2024-12-30 16:00:00  95415.62
# 147 2024-12-31 16:00:00  94439.02
# 148 2025-01-01 16:00:00  96474.98
# 149 2025-01-02 16:00:00  97511.66
#
# [150 rows x 2 columns]), ('huobi',               timestamp     close
# 0   2024-08-06 16:00:00  56099.55
# 1   2024-08-07 16:00:00  59422.08
# 2   2024-08-08 16:00:00  59826.94
# 3   2024-08-09 16:00:00  60512.98
# 4   2024-08-10 16:00:00  60118.47
# ..                  ...       ...
# 145 2024-12-29 16:00:00  92124.04
# 146 2024-12-30 16:00:00  95415.62
# 147 2024-12-31 16:00:00  94439.02
# 148 2025-01-01 16:00:00  96474.98
# 149 2025-01-02 16:00:00  97511.66
#
# [150 rows x 2 columns]), ('indodax',      timestamp          close
# 0   2024-08-06   56773.020000
# 1   2024-08-07   54600.010005
# 2   2024-08-08   62499.989991
# 3   2024-08-09   61000.000000
# 4   2024-08-10   60800.030000
# ..         ...            ...
# 175 2025-01-28  100500.000552
# 176 2025-01-29  102464.195432
# 177 2025-01-30  105331.320000
# 178 2025-01-31  102217.470000
# 179 2025-02-01  100952.000000
#
# [180 rows x 2 columns]), ('mexc',      timestamp      close
# 0   2024-08-06   56023.07
# 1   2024-08-07   55130.01
# 2   2024-08-08   61688.04
# 3   2024-08-09   60828.00
# 4   2024-08-10   60923.52
# ..         ...        ...
# 175 2025-01-28  101335.51
# 176 2025-01-29  103733.24
# 177 2025-01-30  104722.95
# 178 2025-01-31  102429.55
# 179 2025-02-01  100554.16
#
# [180 rows x 2 columns]), ('novadax',      timestamp      close
# 0   2024-08-06   56893.16
# 1   2024-08-07   54948.51
# 2   2024-08-08   61136.66
# 3   2024-08-09   59984.66
# 4   2024-08-10   60731.78
# ..         ...        ...
# 174 2025-01-27  102110.71
# 175 2025-01-28  101369.98
# 176 2025-01-29  103733.24
# 177 2025-01-30  104722.94
# 178 2025-01-31  102415.05
#
# [179 rows x 2 columns]), ('oceanex', Empty DataFrame
# Columns: [timestamp, close]
# Index: []), ('p2b',     timestamp      close
# 0  2024-12-14  101420.00
# 1  2024-12-15  104452.49
# 2  2024-12-16  106058.66
# 3  2024-12-17  106133.74
# 4  2024-12-18  100200.02
# 5  2024-12-19   97461.86
# 6  2024-12-20   97805.44
# 7  2024-12-21   97292.00
# 8  2024-12-22   95186.27
# 9  2024-12-23   94881.46
# 10 2024-12-24   98663.59
# 11 2024-12-25   99429.60
# 12 2024-12-26   95791.60
# 13 2024-12-27   94299.03
# 14 2024-12-28   95300.00
# 15 2024-12-29   93738.20
# 16 2024-12-30   92792.05
# 17 2024-12-31   93576.00
# 18 2025-01-01   94591.79
# 19 2025-01-02   96984.79
# 20 2025-01-03   98174.17
# 21 2025-01-04   98220.50
# 22 2025-01-05   98363.61
# 23 2025-01-06  102235.61
# 24 2025-01-07   96954.61
# 25 2025-01-08   95078.19
# 26 2025-01-09   92552.49
# 27 2025-01-10   94726.11
# 28 2025-01-11   94600.00
# 29 2025-01-12   94545.07
# 30 2025-01-13   94536.10
# 31 2025-01-14   96560.85
# 32 2025-01-15  100497.36
# 33 2025-01-16   99987.29
# 34 2025-01-17  104077.48
# 35 2025-01-18  104556.23
# 36 2025-01-19  101315.87
# 37 2025-01-20  102260.00
# 38 2025-01-21  106143.81
# 39 2025-01-22  103706.66
# 40 2025-01-23  103910.34
# 41 2025-01-24  104870.50
# 42 2025-01-25  104746.85
# 43 2025-01-26  102620.00
# 44 2025-01-27  102082.83
# 45 2025-01-28  101335.52
# 46 2025-01-29  103733.24
# 47 2025-01-30  104722.94
# 48 2025-01-31  102429.55
# 49 2025-02-01  100554.16), ('probit',     timestamp    close
# 0  2024-08-06  56060.0
# 1  2024-08-07  55080.0
# 2  2024-08-08  61693.7
# 3  2024-08-09  60833.5
# 4  2024-08-10  60923.5
# ..        ...      ...
# 95 2024-11-09  76677.5
# 96 2024-11-10  80424.8
# 97 2024-11-11  88646.0
# 98 2024-11-12  87883.9
# 99 2024-11-13  90411.8
#
# [100 rows x 2 columns]), ('timex',    timestamp     close
# 0 2024-10-12   63540.0
# 1 2024-11-19   91315.0
# 2 2024-11-25   95000.0
# 3 2025-01-29  100844.0
# 4 2025-01-30  103112.0
# 5 2025-01-31  101471.0
# 6 2025-02-01  100237.0), ('whitebit',      timestamp      close
# 0   2024-08-06   56024.04
# 1   2024-08-07   55121.01
# 2   2024-08-08   61683.00
# 3   2024-08-09   60831.37
# 4   2024-08-10   60925.98
# ..         ...        ...
# 174 2025-01-27  102091.75
# 175 2025-01-28  101332.47
# 176 2025-01-29  103744.04
# 177 2025-01-30  104724.95
# 178 2025-01-31  102440.28
#
# [179 rows x 2 columns]), ('woo',     timestamp     close
# 0  2024-08-06  56020.77
# 1  2024-08-07  55129.21
# 2  2024-08-08  61689.24
# 3  2024-08-09  60844.72
# 4  2024-08-10  60932.27
# ..        ...       ...
# 95 2024-11-09  76676.98
# 96 2024-11-10  80372.50
# 97 2024-11-11  88652.51
# 98 2024-11-12  87951.56
# 99 2024-11-13  90367.45
#
# [100 rows x 2 columns]), ('xt',     timestamp      close
# 0  2024-10-25   66698.32
# 1  2024-10-26   67092.76
# 2  2024-10-27   68021.69
# 3  2024-10-28   69962.21
# 4  2024-10-29   72736.42
# ..        ...        ...
# 95 2025-01-28  101343.64
# 96 2025-01-29  103733.24
# 97 2025-01-30  104722.94
# 98 2025-01-31  102428.31
# 99 2025-02-01  100576.20
#
# [100 rows x 2 columns]), ('zonda',     timestamp         close
# 0  2024-08-06  56032.027064
# 1  2024-08-07  55370.457000
# 2  2024-08-08  61847.211990
# 3  2024-08-09  60407.060223
# 4  2024-08-10  60995.768000
# ..        ...           ...
# 95 2024-11-09  76646.786458
# 96 2024-11-10  80150.000000
# 97 2024-11-11  88536.881002
# 98 2024-11-12  87833.328081
# 99 2024-11-13  90357.592224
#
# [100 rows x 2 columns])]
#      exchange1 exchange2  average_arbitrage_percent  max_arbitrage_percent  \
# 65         p2b     timex                   2.213690               2.865059
# 42      fmfwio     timex                   2.178366               2.884108
# 13  bitcoincom     timex                   2.178366               2.884108
# 6      bequant     timex                   2.178366               2.884108
# 46     hollaex     timex                   2.131553               2.772808
# ..         ...       ...                        ...                    ...
# 4     ascendex     zonda                   1.023769               1.023769
# 59        mexc     zonda                   1.023330               1.023330
# 18     bitmart     zonda                   1.023330               1.023330
# 71          xt     zonda                   1.023315               1.023315
# 69    whitebit     zonda                   1.019286               1.019286
#
#     opportunity_count
# 65                  2
# 42                  3
# 13                  3
# 6                   3
# 46                  3
# ..                ...
# 4                   1
# 59                  1
# 18                  1
# 71                  1
# 69                  1
#
# [72 rows x 5 columns]
